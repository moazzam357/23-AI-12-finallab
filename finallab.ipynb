# %%
import pandas as pd

df = pd.read_csv("mystery_data.csv")

# %% [markdown]
# Index  ID   Age  Sex  Score1  Score2

# %%
import pandas as pd


df = pd.read_csv("mystery_data.csv", header=None)


df.columns = ['ID', 'Age', 'Sex', 'Score1', 'Score2']


df
# Out:
#      ID  Age Sex  Score1  Score2
# 0   101   40   M     5.6      45
# 1   102   90   M    10.3      97
# 2   103   84   F     7.7      98
# 3   104   52   M    11.6      98
# 4   105   43   F     8.4      47
# ..  ...  ...  ..     ...     ...
# 95  196   42   M    10.2      61
# 96  197   66   M    10.9      65
# 97  198   68   F    10.6      58
# 98  199   71   M     7.9      53
# 99  200   89   M    10.1      90
#
# [100 rows x 5 columns]

# %%
df.rename(columns={'Sex': 'Gender'},{'Score1'}, inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-8-1230286195.py in <cell line: 0>()
# ----> 1 kaiser
#
# NameError: name 'kaiser' is not defined
